# %%
import numpy as np
import os

data_path = '../../data/realism/'

# %% [markdown]
# # Load data

# %%
files = os.listdir(data_path)
print(files)
pred_inst = np.load(data_path+'lizard_prediction_instance_3class_Noise_0_pretrain_data_v1_6 (1).npy', allow_pickle=True)

imgs_inst = np.load(data_path+'images_instance_3class_Noise_0_pretrain_data_v1_6.npy', allow_pickle=True)
# Out:
# ['eval_model_on_lizard_FG_BG_Noise_0_pretrain_data_v1_6.npy', 'eval_model_on_lizard_instance_3class_Noise_0_pretrain_data_v1_6.npy', 'images_FG_BG_Noise_0_pretrain_data_v1_6.npy', 'images_instance_3class_Noise_0_pretrain_data_v1_6.npy', 'lizard_prediction_FG_BG_Noise_0_pretrain_data_v1_6.npy', 'lizard_prediction_instance_3class_Noise_0_pretrain_data_v1_6 (1).npy', 'true_labels_FG_BG_Noise_0_pretrain_data_v1_6.npy', 'true_labels_instance_3class_Noise_0_pretrain_data_v1_6.npy']

# %%
i = 10

import matplotlib.pyplot as plt
fig, axs = plt.subplots(1, 2)
axs[0].imshow(imgs_inst[i])
axs[1].imshow(pred_inst[i])
