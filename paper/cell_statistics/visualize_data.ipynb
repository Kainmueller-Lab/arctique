# %%
import numpy as np
import matplotlib.pyplot as plt

n = 0

### Import images and display an image
imgs = np.load('images.npy')
plt.imshow(imgs[n])
plt.show()

# %%
### Import labels and display one
import numpy as np
import matplotlib.pyplot as plt

labs = np.load('labels.npy')
plt.imshow(labs[5,:,:,0]) #-------------------------- Why 2 channels? - 1. instance seg; 2. semantic channel 
plt.savefig('label_5.png',dpi=300)
plt.show()
